# %%
x=float(input())
x=int(x)
print(x)
# Out:
#  4.6
# 4

# %%
def primenumber():
    x=int(input())
    for i in range(2,x):
        if x%i==0:
            print("khong phai so nguyen to")
            break
        else:
            print("so nguyen to")
            break
primenumber()
# Out:
#  5
# so nguyen to
