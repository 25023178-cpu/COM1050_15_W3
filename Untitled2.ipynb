# %% [markdown]
# # A1

# %%
n=int(input())
sum=0
for i in range(1,n+1):
    sum+=i
print(sum)
# Out:
#  3
# 6

# %% [markdown]
# # A2

# %%
def primenumber():
    x=int(input())
    for i in range(2,x):
        if x%i==0:
            print("khong phai so nguyen to")
            break
        else:
            print("so nguyen to")
            break
primenumber()
# Out:
#  6
# khong phai so nguyen to
