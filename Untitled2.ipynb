# %% [markdown]
# # A1

# %%
n=int(input())
sum=0
for i in range(1,n+1):
    sum+=i
print(sum)
# Out:
#  3
# 6

# %% [markdown]
# # A2

# %%
def primenumber():
    x=float(input())
    if x%1!=0 and x<0:
       return primenumber()
    
    if x%int(n)==0:
       print("may khong la so nguyen to")
    else:
       print("may la so nguyen to")
primenumber()
